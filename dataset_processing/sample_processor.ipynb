# %%
import os
import pandas as pd
from pathlib import Path
from collections import defaultdict

# %%
DATASET_PATH = Path(os.path.abspath('')).parent / 'dataset'
RAW_PATH = DATASET_PATH / 'test'
SPLITTED_PATH = DATASET_PATH / 'test'
DT_COL = 'event_time'

# %%
df = pd.read_csv(RAW_PATH / 'data_2019-10-01.csv', parse_dates=[DT_COL])
df.to_parquet(f'{SPLITTED_PATH}/data_2025-10-01_1.parquet', index=False)
